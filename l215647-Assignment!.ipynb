# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here
def check_input(test1,count):
  for row in test1:
    for col in row:
      if(col==1):
        count=count+1
      elif(col==2):
         count=count+1
      elif(col==3):
          count=count+1   

  if(count==len(test1)*len(test1)):
    return True
  else:
    return False

# %%
# run this block to test code after defining the procedure
count=0
test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1,count)) # must return true
print(check_input(test2,count)) # must return false
print(check_input(test3,count)) # must return false
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("StudentMarkSheet.csv")
print(data)
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
print("rows before removing ",len(data))
data=data.dropna()
print("rows after removing ",len(data))
# Out:
# rows before removing  200
# rows after removing  196

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
data.loc[data['Student name']=="James Walker"]
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
biology = data[['Exam name', 'Marks']]
biology=biology.loc[data['Exam name']=="Biology"]
avgbio=biology.loc['Marks']=biology.sum(numeric_only=True,axis=0)
avgbio=avgbio/len(biology)
print("average biology ",avgbio) 

maths = data[['Exam name', 'Marks']]
maths=maths.loc[data['Exam name']=="Mathematics"]
avgmaths=maths.loc['Marks']=maths.sum(numeric_only=True,axis=0)
avgmaths=avgmaths/len(maths)
print("average maths ",avgmaths)

chem = data[['Exam name', 'Marks']]
chem=chem.loc[data['Exam name']=="Chemistry"]
avgchem=chem.loc['Marks']=chem.sum(numeric_only=True,axis=0)
avgchem=avgchem/len(chem)
print("average chemistry ",avgchem)

phil = data[['Exam name', 'Marks']]
phil=phil.loc[data['Exam name']=="Philosophy"]
avgphil=phil.loc['Marks']=phil.sum(numeric_only=True,axis=0)
avgphil=avgphil/len(phil)
print("average philosophy ",avgphil)

phy = data[['Exam name', 'Marks']]
phy=phy.loc[data['Exam name']=="Physics"]
avgphy=phy.loc['Marks']=phy.sum(numeric_only=True,axis=0)
avgphy=avgphy/len(phy)
print("average physics ",avgphy)

socio = data[['Exam name', 'Marks']]
socio=socio.loc[data['Exam name']=="Sociology"]
avgsocio=socio.loc['Marks']=socio.sum(numeric_only=True,axis=0)
avgsocio=avgsocio/len(socio)
print("average Sociology  ",avgsocio)
# Out:
# average biology  Marks    46.666667
# dtype: float64
# average maths  Marks    47.648649
# dtype: float64
# average chemistry  Marks    48.703704
# dtype: float64
# average philosophy  Marks    46.026316
# dtype: float64
# average physics  Marks    49.409091
# dtype: float64
# average Sociology   Marks    54.589744
# dtype: float64

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
plt.xlabel("SUBJECTS")
plt.ylabel("AVERAGE")
x='maths'
y=avgmaths
plt.bar(x,y)
x='biology'
y=avgbio
plt.bar(x,y)
x='chemistry'
y=avgchem
plt.bar(x,y)
x='sociology'
y=avgsocio
plt.bar(x,y)
x='physics'
y=avgphy
plt.bar(x,y)
x='phylosophy'
y=avgphil
plt.bar(x,y)
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("CatData.csv")
data=data.dropna()
data
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [342 rows x 2 columns]

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
#data = data[["Tail Length (cm)","Mass (kg)"]]
# dependant variable:
Yi=np.array(data[["Tail Length (cm)"]])
# independant variable: 
Xi=np.array(data[["Mass (kg)"]])

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
n=len(Xi)
 #X bar:
Xi_mean = Xi.mean()
    
    #Y bar:
Yi_mean = Yi.mean()
    
    #Sum of X:
S_Xi = (Xi).sum()
   
    #Sum of Y:
S_Yi = (Yi).sum()
 
#Sum of (X*Y) multiplied by n:
S_XiYi = ((Xi*Yi).sum())*n

    #Sum of X*Sum of Y:
S_Xi_S_Yi = S_Xi*S_Yi
    
    #Sum of (X*X) multiplied by n:
S_XiXi = ((Xi*Xi).sum())*n   
    #Square of sum of X:
S_Xi_Square = S_Xi*S_Xi
    
    #Slope:
slope = (S_XiYi- S_Xi_S_Yi) / (S_XiXi-S_Xi_Square)
    
    #Intercept:
intercept = Yi_mean - slope * Xi_mean

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
print("value for slope ",slope)
print("value for intercept ",intercept)
# Out:
# value for slope  1.527591560803727
# value for intercept  13.672955927266212

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.scatter(Xi,Yi)
plt.plot(Xi,slope*Xi+intercept,color="red")
plt.xlabel("MASS")
plt.ylabel("TAIL LENGTH")
plt.show()
